# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhishek95781/apnacollege-demo/blob/main/Abhishek.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 5
b = 6
print(a+b)
# Out:
# 11
